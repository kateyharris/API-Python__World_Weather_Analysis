# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.

# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import requests
import json
from citipy import citipy
# Import the API key.
from config import weather_api_key

# %%
# Create a new set of 2,000 random latitudes and longitudes.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
coordinates = list(zip(lats, lngs))

# %%
# Get the nearest city using the citipy module.

# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
        
# Build the city_url or endpoint for each city.
url = "http://api.openweathermap.org/data/2.5/weather?q="

# Create an empty list to hold the weather data.
city_data = []

# Perform an API call with the OpenWeatherMap.
# Loop through all the cities in the list.
for city in cities:
    city_url = url + city.replace(" ","+") + "&units=imperial&appid=" + weather_api_key 
    city_weather = requests.get(city_url).json()
    try:
        # Retrieve the following information from the API call:
            # Latitude and longitude
            # Maximum temperature
            # Percent humidity
            # Percent cloudiness
            # Wind speed
            # Weather description (for example, clouds, fog, light rain, clear sky)
        city_country = city_weather["sys"]["country"]
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        weather_desc = city_weather["weather"][0]["description"]
        # Add the data to a list in a dictionary format
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Weather Description": weather_desc})
        print(f"{city} found")
# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# ushuaia found
# hobart found
# City not found. Skipping...
# arraial do cabo found
# punta arenas found
# talnakh found
# busselton found
# matongo found
# dikson found
# port elizabeth found
# tezu found
# mednogorsk found
# kodiak found
# City not found. Skipping...
# tuktoyaktuk found
# san andres found
# vaini found
# ola found
# uong bi found
# lodwar found
# saint george found
# rikitea found
# aykhal found
# City not found. Skipping...
# atuona found
# cape town found
# City not found. Skipping...
# coihaique found
# puerto ayora found
# grindavik found
# kapaa found
# City not found. Skipping...
# hasaki found
# port alfred found
# port hardy found
# georgetown found
# flinders found
# tianpeng found
# alihe found
# andenes found
# City not found. Skipping...
# albany found
# hermanus found
# City not found. Skipping...
# banjar found
# korla found
# ngunguru found
# City not found. Skipping...
# jacareacanga found
# kununurra found
# airai found
# yellowknife found
# jamestown found
# City not found. Skipping...
# makakilo city found
# masterton found
# lebyazhye found
# charters towers found
# pindi gheb found
# pasighat found
# kilis found
# yar-sale found
# chuy found
# san cristobal found
# butaritari found
# bonoua found
# bluff found
# bethel found
# nikolskoye found
# qaanaaq found
# port keats found
# victoria found
# bandarbeyla found
# City not found. Skipping...
# george town found
# nanortalik found
# rocha found
# kavieng found
# City not found. Skipping...
# chulman found
# severo-kurilsk found
# vostok found
# casanayan found
# barrow found
# buenos aires found
# sitka found
# esna found
# bell ville found
# tomsani found
# ambunti found
# lagoa found
# iqaluit found
# libenge found
# linxia found
# eyl found
# lebu found
# qasigiannguit found
# City not found. Skipping...
# mataura found
# padang found
# morros found
# ostrovnoy found
# bredasdorp found
# tevaitoa found
# ponta do sol found
# bengkulu found
# maceio found
# avarua found
# City not found. Skipping...
# coahuayana found
# vila franca do campo found
# daru found
# vung tau found
# City not found. Skipping...
# cherskiy found
# hilo found
# belmonte found
# cururupu found
# laranjeiras do sul found
# oum hadjer found
# alta floresta found
# City not found. Skipping...
# sioux lookout found
# saldanha found
# boyolangu found
# komsomolskiy found
# doha found
# changji found
# oistins found
# leningradskiy found
# east london found
# arman found
# hofn found
# asau found
# salantai found
# praia da vitoria found
# pevek found
# jinxiang found
# wajir found
# merauke found
# camacha found
# kruisfontein found
# goure found
# imamoglu found
# kodinsk found
# klimovo found
# cabo san lucas found
# saint anthony found
# bambanglipuro found
# nanakuli found
# evensk found
# simbahan found
# sechura found
# codrington found
# beringovskiy found
# carnarvon found
# lompoc found
# sherbakul found
# magdagachi found
# sobolevo found
# clyde river found
# hithadhoo found
# lander found
# puerto escondido found
# capljina found
# weyburn found
# manuk mangkaw found
# aklavik found
# thompson found
# ancud found
# rangapara found
# castro found
# quatre cocos found
# estepa found
# pangnirtung found
# senanga found
# fortuna found
# puerto quijarro found
# City not found. Skipping...
# ayagoz found
# zhuhai found
# walvis bay found
# portland found
# mount isa found
# sao filipe found
# hamilton found
# lazaro cardenas found
# jacksonville found
# florianopolis found
# khatanga found
# touros found
# harlingen found
# half moon bay found
# chokurdakh found
# City not found. Skipping...
# santa cruz found
# juneau found
# ust-kulom found
# asheville found
# warragul found
# grand-lahou found
# xichang found
# City not found. Skipping...
# saskylakh found
# nuuk found
# new norfolk found
# lorengau found
# bulanash found
# longyearbyen found
# moussoro found
# City not found. Skipping...
# torbay found
# pakxan found
# ballitoville found
# kawalu found
# manggar found
# sayyan found
# danilov found
# khandagayty found
# kabare found
# yulara found
# bagdarin found
# uribia found
# bubaque found
# klaksvik found
# mao found
# fukue found
# lumeje found
# te anau found
# aswan found
# arlit found
# marzuq found
# savannakhet found
# vestmannaeyjar found
# City not found. Skipping...
# bereda found
# shigony found
# City not found. Skipping...
# angoche found
# nabire found
# luanshya found
# cuicatlan found
# oktyabrskiy found
# City not found. Skipping...
# cidreira found
# provideniya found
# vila velha found
# kiunga found
# luderitz found
# tiksi found
# poum found
# City not found. Skipping...
# aranos found
# mahebourg found
# dunedin found
# City not found. Skipping...
# tyler found
# ribeira grande found
# souillac found
# olafsvik found
# crib point found
# darab found
# nouakchott found
# pitkyaranta found
# kahului found
# cayenne found
# egvekinot found
# tasiilaq found
# homnabad found
# haines junction found
# ponta delgada found
# hope found
# tucumcari found
# aizkraukle found
# ilulissat found
# nicoya found
# katsuura found
# casino found
# nehe found
# burnie found
# koryukivka found
# champerico found
# faanui found
# labuhan found
# saint-philippe found
# mitsamiouli found
# payson found
# bayir found
# isiro found
# duobao found
# north bend found
# ambo found
# balaka found
# sinnamary found
# upernavik found
# City not found. Skipping...
# City not found. Skipping...
# sao francisco do sul found
# shubarkuduk found
# pirenopolis found
# celestun found
# kuytun found
# laguna found
# deputatskiy found
# andros town found
# astana found
# City not found. Skipping...
# City not found. Skipping...
# xining found
# koroni found
# jennings found
# huicheng found
# pisco found
# City not found. Skipping...
# khor found
# sibolga found
# alyangula found
# camacupa found
# tuatapere found
# lukovetskiy found
# graneros found
# waingapu found
# metsavan found
# mount gambier found
# itarema found
# ballina found
# satana found
# yumen found
# mandalgovi found
# esperance found
# marawi found
# troitskoye found
# mollendo found
# eureka found
# City not found. Skipping...
# qinhuangdao found
# sola found
# san quintin found
# harrisonburg found
# toledo found
# nemuro found
# pyaozerskiy found
# fairbanks found
# mar del plata found
# wakkanai found
# sao felix do xingu found
# gravdal found
# kaitangata found
# illapel found
# nara found
# srednebelaya found
# huarmey found
# tautira found
# krutaya gorka found
# thinadhoo found
# dingle found
# kargasok found
# nichinan found
# kamenka found
# constitucion found
# kaeo found
# sampit found
# tatawin found
# portobelo found
# cedar city found
# college found
# hovd found
# mumford found
# chumphon found
# City not found. Skipping...
# lazurne found
# puerto narino found
# rawson found
# leninsk-kuznetskiy found
# burntwood found
# hualmay found
# City not found. Skipping...
# bairiki found
# City not found. Skipping...
# mosquera found
# salalah found
# bileca found
# City not found. Skipping...
# norman wells found
# sakakah found
# seymchan found
# ise found
# vanimo found
# bathsheba found
# kayerkan found
# darhan found
# aksarka found
# nome found
# sonkovo found
# birin found
# hambantota found
# caravelas found
# najran found
# narsaq found
# husavik found
# iskateley found
# mahanoro found
# port-cartier found
# namwala found
# tazovskiy found
# puerto carreno found
# kawambwa found
# quepos found
# woodstock found
# filingue found
# sambava found
# shar found
# qaqortoq found
# City not found. Skipping...
# sao joao da barra found
# fuyang found
# san patricio found
# diapaga found
# beba found
# sabang found
# saint-joseph found
# naryan-mar found
# bahia blanca found
# murray bridge found
# la maddalena found
# chapais found
# behshahr found
# tatarskaya kargala found
# axim found
# tommot found
# dwarka found
# ust-kuyga found
# ust-nera found
# nagapattinam found
# inirida found
# jardim found
# cheremisinovo found
# preobrazheniye found
# osoyoos found
# buala found
# calama found
# City not found. Skipping...
# dauphin found
# yaan found
# lewiston found
# bogande found
# energetik found
# novobelokatay found
# kaka found
# plettenberg bay found
# barcelos found
# pella found
# yerbogachen found
# storsteinnes found
# isangel found
# haapiti found
# macapa found
# prince rupert found
# nawabshah found
# la mana found
# City not found. Skipping...
# vilyuysk found
# san juan found
# pitimbu found
# todos santos found
# mahasamund found
# okhotsk found
# jamkhed found
# panaba found
# neiafu found
# dudinka found
# dalian found
# vardo found
# le port found
# hay river found
# catamarca found
# mananjary found
# kang found
# belyy yar found
# vao found
# baoying found
# kangema found
# fort smith found
# port macquarie found
# broken hill found
# vilhena found
# sehwan found
# lasa found
# la ronge found
# vitim found
# port lincoln found
# guerrero negro found
# faya found
# kavaratti found
# poso found
# san javier found
# fontanafredda found
# hollister found
# nagua found
# havre-saint-pierre found
# cumbitara found
# petropavlovsk-kamchatskiy found
# jiuquan found
# gamba found
# City not found. Skipping...
# ixtapa found
# hanover found
# meulaboh found
# hervey bay found
# balkhash found
# nuevo progreso found
# port shepstone found
# hermosillo found
# navalmoral de la mata found
# progreso found
# hinton found
# rafaela found
# tahta found
# kragujevac found
# inhambane found
# lebanon found
# duluth found
# alofi found
# yeppoon found
# City not found. Skipping...
# jumla found
# sao miguel do araguaia found
# kangaatsiaq found
# fort beaufort found
# bay roberts found
# maniitsoq found
# vada found
# sovetskiy found
# imeni poliny osipenko found
# itoman found
# tura found
# City not found. Skipping...
# sheffield found
# loa janan found
# buenaventura found
# tazmalt found
# ossora found
# dasoguz found
# nyurba found
# namibe found
# kapasan found
# jiazi found
# cap malheureux found
# hirara found
# totolapa found
# kerman found
# teguldet found
# cairns found
# tarrafal found
# aripuana found
# road town found
# victoria point found
# mehriz found
# harindanga found
# yatou found
# City not found. Skipping...
# City not found. Skipping...
# bulawayo found
# boromo found
# indergarh found
# bima found
# bilma found
# kisangani found
# City not found. Skipping...
# sibu found
# gotsu found
# tokonou found
# bambous virieux found
# ostersund found
# srbac found
# City not found. Skipping...
# novikovo found
# suifenhe found
# matara found
# rio grande found
# roald found
# nishihara found
# pont-audemer found
# City not found. Skipping...
# vianopolis found
# bol found
# arrecife found
# City not found. Skipping...
# kazachinskoye found
# auki found
# gigmoto found
# sao borja found
# darnah found
# geraldton found
# atlantis found
# City not found. Skipping...
# iida found
# sheltozero found
# huilong found
# tabuk found
# verkhnyaya inta found
# baiyin found
# carutapera found
# enfield found
# hami found
# makokou found
# saint-denis found
# mayo found
# City not found. Skipping...
# lata found
# kendari found
# victor harbor found
# shingu found
# kulhudhuffushi found
# stornoway found
# thessalon found
# barra da estiva found
# jalhay found
# jiwani found
# moldava nad bodvou found
# kokopo found
# mehamn found
# camalu found
# srednekolymsk found
# sirjan found
# tobane found
# City not found. Skipping...
# snezhnogorsk found
# quincy found
# westport found
# matay found
# kuching found
# banda aceh found
# tigil found
# pithapuram found
# sabla found
# port-gentil found
# pemba found
# City not found. Skipping...
# port augusta found
# praia found
# lagunas found
# juegang found
# ust-ishim found
# strezhevoy found
# ikwiriri found
# lavrentiya found
# bonavista found
# ilanskiy found
# negombo found
# santa marinella found
# beian found
# sokolow podlaski found
# nouadhibou found
# adrar found
# zhigansk found
# kasongo-lunda found
# bangassou found
# raga found
# ampanihy found
# mayor pablo lagerenza found
# nago found
# City not found. Skipping...
# shimoda found
# ribeira brava found
# gisborne found
# ahipara found
# santa pola found
# emba found
# City not found. Skipping...
# barra patuca found
# lufilufi found
# amboasary found
# City not found. Skipping...
# kloulklubed found
# burley found
# dawlatabad found
# kindu found
# ozernovskiy found
# ketchikan found
# horasan found
# lincoln found
# City not found. Skipping...
# City not found. Skipping...
# ajdabiya found
# kirakira found
# tamale found
# pangai found
# City not found. Skipping...
# pochutla found
# etchojoa found
# kidal found
# trincomalee found
# dukat found
# suzhou found
# City not found. Skipping...
# halifax found
# yanliang found
# akdagmadeni found
# iranshahr found
# bakchar found
# City not found. Skipping...
# impfondo found
# vuktyl found
# valparaiso found
# lishui found
# thunder bay found
# karatau found
# hurghada found
# warmbad found
# almonte found
# khangarh found
# podyuga found
# comodoro rivadavia found
# kharod found
# naze found
# quelimane found
# douala found
# zalantun found
# sorland found
# pacifica found
# kostelec nad orlici found
# kaifeng found
# zigos found
# kahramanmaras found
# kunya found
# City not found. Skipping...
# koumac found
# mpongwe found
# City not found. Skipping...
# City not found. Skipping...
# maloy found
# chulym found
# labytnangi found
# russkiy aktash found
# newala found
# chicama found
# west wendover found
# sumbe found
# hokitika found
# ler found
# escanaba found
# huaraz found
# ulaanbaatar found
# ada found
# City not found. Skipping...
# City not found. Skipping...
# corralillo found
# boa vista found
# kaduy found
# malakal found
# pervomayskoye found
# vila found
# kurilsk found
# yala found
# manta found
# City not found. Skipping...
# nizhniy lomov found
# takoradi found
# maragogi found
# kilindoni found
# grand forks found
# City not found. Skipping...
# dimbokro found
# City not found. Skipping...
# mahon found
# ust-koksa found
# poiana cristei found
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 702

# %%
# Add the data to a new DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#               City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0          Ushuaia      AR -54.8000  -68.3000     62.26        31          20
# 1           Hobart      AU -42.8794  147.3294     48.11        95          90
# 2  Arraial Do Cabo      BR -22.9661  -42.0278     76.96        83          75
# 3     Punta Arenas      CL -53.1500  -70.9167     60.91        51          75
# 4          Talnakh      RU  69.4865   88.3972     -5.64        96         100
# 5        Busselton      AU -33.6500  115.3333     40.05        83          17
# 6          Matongo      TZ  -2.3833   34.0833     75.83        49          99
# 7           Dikson      RU  73.5069   80.5464      7.66        92         100
# 8   Port Elizabeth      ZA -33.9180   25.5701     69.10        94          40
# 9             Tezu      IN  27.9167   96.1667     66.13        54           0
#
#    Wind Speed Weather Description
# 0       16.11          few clouds
# 1        5.01       moderate rain
# 2       13.80       broken clouds
# 3       16.11       broken clouds
# 4        9.28     overcast clouds
# 5        8.34          few clouds
# 6        3.36     overcast clouds
# 7        9.73     overcast clouds
# 8        4.61          light rain
# 9        4.34           clear sky

# %%
# Export the DataFrame as a CSV file, and save it as WeatherPy_Database.csv in the Weather_Database folder.
output_data_file = "WeatherPy_Database.csv"
city_data_df.to_csv(output_data_file, index_label="City_ID")
