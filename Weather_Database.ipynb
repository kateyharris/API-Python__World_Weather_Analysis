# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import requests
import json
from citipy import citipy
# Import the API key.
from config import weather_api_key

# %%
# Create a new set of 2,000 random latitudes and longitudes.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
coordinates = list(zip(lats, lngs))

# %%
# Get the nearest city using the citipy module.

# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
        
# Build the city_url or endpoint for each city.
url = "http://api.openweathermap.org/data/2.5/weather?q="

# Create an empty list to hold the weather data.
city_data = []

# Perform an API call with the OpenWeatherMap.
# Loop through all the cities in the list.
for city in cities:
    city_url = url + city.replace(" ","+") + "&units=imperial&appid=" + weather_api_key 
    city_weather = requests.get(city_url).json()
    try:
        # Retrieve the following information from the API call:
            # Latitude and longitude
            # Maximum temperature
            # Percent humidity
            # Percent cloudiness
            # Wind speed
            # Weather description (for example, clouds, fog, light rain, clear sky)
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        weather_desc = city_weather["weather"][0]["description"]
        # Add the data to a list in a dictionary format
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Weather Description": weather_desc})
        print(f"{city} found")
# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# rikitea found
# barentu found
# saint george found
# vardo found
# general jose eduvigis diaz found
# srednekolymsk found
# hualmay found
# qaqortoq found
# butaritari found
# sitka found
# mar del plata found
# ushuaia found
# cape town found
# chuy found
# City not found. Skipping...
# mataura found
# morogoro found
# pringsewu found
# erzin found
# port alfred found
# cabedelo found
# port elizabeth found
# saint-philippe found
# busselton found
# bluff found
# san ramon found
# hobart found
# castro found
# City not found. Skipping...
# hilo found
# guerrero negro found
# north platte found
# City not found. Skipping...
# hermanus found
# upernavik found
# City not found. Skipping...
# airai found
# narimanov found
# carnarvon found
# chiredzi found
# alta floresta found
# City not found. Skipping...
# City not found. Skipping...
# ilulissat found
# san patricio found
# sarh found
# norman wells found
# qaanaaq found
# City not found. Skipping...
# albany found
# provideniya found
# coos bay found
# City not found. Skipping...
# guarapari found
# paracatu found
# punta arenas found
# yumen found
# yellowknife found
# dikson found
# shache found
# pemangkat found
# jamestown found
# santa cruz found
# ostrovnoy found
# pathein found
# jardim found
# lensk found
# waipawa found
# City not found. Skipping...
# atar found
# beroroha found
# pandan found
# nikolskoye found
# bjornevatn found
# kyra found
# mount gambier found
# avarua found
# raudeberg found
# rovenki found
# tommot found
# krabi found
# tuktoyaktuk found
# ribeira grande found
# reconquista found
# shizuishan found
# khatanga found
# tasiilaq found
# souillac found
# georgetown found
# City not found. Skipping...
# longyearbyen found
# eucaliptus found
# lompoc found
# City not found. Skipping...
# killybegs found
# missoula found
# tiksi found
# buala found
# dano found
# cockburn town found
# batagay-alyta found
# rodas found
# torbay found
# mount isa found
# mizdah found
# City not found. Skipping...
# saint-joseph found
# avera found
# geraldton found
# san cristobal found
# atuona found
# lyantonde found
# caravelas found
# sokoto found
# nuuk found
# merauke found
# City not found. Skipping...
# cidreira found
# bairnsdale found
# naze found
# bredasdorp found
# City not found. Skipping...
# kavieng found
# esmeralda found
# City not found. Skipping...
# new norfolk found
# muli found
# saskylakh found
# ponta delgada found
# thompson found
# City not found. Skipping...
# okhotsk found
# severo-kurilsk found
# City not found. Skipping...
# matara found
# puerto ayora found
# City not found. Skipping...
# vaini found
# touho found
# saint anthony found
# trelew found
# isla mujeres found
# zdvinsk found
# aksu found
# san carlos found
# klaksvik found
# paamiut found
# aqtobe found
# korem found
# bay city found
# pisco found
# lebu found
# City not found. Skipping...
# plouzane found
# kodiak found
# kidal found
# vredendal found
# chokurdakh found
# yarmouth found
# City not found. Skipping...
# nanortalik found
# arraial do cabo found
# kuytun found
# conde found
# meulaboh found
# acarau found
# alekseyevka found
# hambantota found
# lodja found
# bereda found
# promyshlennyy found
# cabittaogan found
# hunfeld found
# bacalar found
# kaitangata found
# City not found. Skipping...
# abu kamal found
# bethel found
# adrar found
# narsaq found
# cherskiy found
# bairiki found
# walvis bay found
# svetlogorsk found
# puerto madryn found
# yulara found
# encruzilhada found
# City not found. Skipping...
# nabire found
# natal found
# nova londrina found
# broken hill found
# denpasar found
# lyubech found
# abatskoye found
# palotina found
# czluchow found
# shitanjing found
# college found
# hithadhoo found
# fortuna found
# bengkulu found
# kapaa found
# zhigansk found
# faanui found
# port lincoln found
# bathsheba found
# gushikawa found
# marsh harbour found
# iqaluit found
# nemuro found
# yar-sale found
# shingu found
# ust-kuyga found
# kuhdasht found
# sananduva found
# forbes found
# tsybli found
# xining found
# hay river found
# baculin found
# City not found. Skipping...
# benghazi found
# neryungri found
# barrow found
# pevek found
# City not found. Skipping...
# kismayo found
# east london found
# City not found. Skipping...
# mazagao found
# nicoya found
# sinnamary found
# saldanha found
# fenelon falls found
# fairbanks found
# camacupa found
# tuatapere found
# sao filipe found
# bambous virieux found
# dwarka found
# vanimo found
# clyde river found
# nouadhibou found
# kashan found
# kabwe found
# prince rupert found
# terrak found
# port pirie found
# belaya gora found
# alice springs found
# saint-francois found
# waingapu found
# komsomolskiy found
# lang son found
# City not found. Skipping...
# asau found
# labuhan found
# azangaro found
# maniitsoq found
# sola found
# rawson found
# broome found
# puerto leguizamo found
# ancud found
# kruisfontein found
# ponta do sol found
# tomatlan found
# dzaoudzi found
# talara found
# salamanca found
# hasaki found
# bonfim found
# City not found. Skipping...
# kariba found
# sitio novo do tocantins found
# alofi found
# lerwick found
# mangrol found
# vila velha found
# lorengau found
# quepos found
# olavarria found
# bose found
# City not found. Skipping...
# City not found. Skipping...
# loreto found
# tongzi found
# esik found
# byron bay found
# aguadilla found
# sumkino found
# City not found. Skipping...
# nanzhang found
# bocana de paiwas found
# burbank found
# groton found
# staraya mayna found
# harper found
# quatre cocos found
# champerico found
# faya found
# qostanay found
# zihuatanejo found
# islamkot found
# manadhoo found
# dingle found
# samarai found
# bhind found
# awjilah found
# orlik found
# hamilton found
# maragua found
# seymchan found
# eldorado found
# wahlstedt found
# bayshore gardens found
# roma found
# sukumo found
# beringovskiy found
# namibe found
# maningrida found
# nome found
# amapa found
# victoria found
# mitsamiouli found
# springbok found
# los llanos de aridane found
# pochutla found
# le mars found
# codrington found
# talnakh found
# svetlyy found
# inuvik found
# turukhansk found
# turbo found
# marawi found
# ballina found
# City not found. Skipping...
# tsabong found
# urucara found
# nadym found
# sept-iles found
# peleduy found
# City not found. Skipping...
# loncoche found
# la reforma found
# lewistown found
# duyure found
# xiaoweizhai found
# cedar city found
# jadu found
# te anau found
# kieta found
# gizo found
# chapais found
# tiznit found
# maceio found
# esperance found
# den helder found
# khani found
# flinders found
# steamboat springs found
# camocim found
# tigre found
# tanhacu found
# panaba found
# hailar found
# tigzirt found
# arrecife found
# vao found
# asfi found
# pangnirtung found
# husavik found
# nola found
# kanker found
# pryyutivka found
# presidencia roque saenz pena found
# hofn found
# thinadhoo found
# shirokiy found
# leningradskiy found
# tulum found
# kondinskoye found
# constitucion found
# bukachacha found
# maragogi found
# porvoo found
# shadegan found
# City not found. Skipping...
# laurel found
# grindavik found
# bara found
# uthal found
# petropavlovsk-kamchatskiy found
# newcastle found
# City not found. Skipping...
# luba found
# herat found
# kirensk found
# mormugao found
# manokwari found
# City not found. Skipping...
# westport found
# ola found
# qarqin found
# payakumbuh found
# mahebourg found
# edson found
# troitskoye found
# nishihara found
# watsa found
# fort myers beach found
# siteki found
# pangody found
# sokoni found
# stege found
# darhan found
# yeppoon found
# nelson bay found
# honningsvag found
# gamba found
# antigonish found
# yanam found
# nybro found
# kenora found
# manching found
# richards bay found
# kurayoshi found
# tocopilla found
# rock sound found
# carbonia found
# puerto escondido found
# bethanien found
# lake city found
# la tuque found
# kaeo found
# baruun-urt found
# baherden found
# calvinia found
# shahdadkot found
# cayenne found
# merrill found
# City not found. Skipping...
# lakhdenpokhya found
# arys found
# anito found
# pontianak found
# igrim found
# batticaloa found
# City not found. Skipping...
# miri found
# malakal found
# twentynine palms found
# kahului found
# katsuura found
# phimai found
# pemba found
# manzhouli found
# uribia found
# san carlos de bariloche found
# diffa found
# laguna found
# bosaso found
# olhao found
# forestville found
# havre-saint-pierre found
# whyalla found
# malanje found
# deputatskiy found
# City not found. Skipping...
# akyab found
# kirakira found
# wanning found
# ust-nera found
# bubaque found
# olafsvik found
# altagracia de orituco found
# poum found
# puerto del rosario found
# marabba found
# tayzhina found
# City not found. Skipping...
# cajabamba found
# half moon bay found
# xuddur found
# rabo de peixe found
# helong found
# kavaratti found
# basoko found
# leskovik found
# manaus found
# zabol found
# barra do garcas found
# padang found
# caruray found
# City not found. Skipping...
# City not found. Skipping...
# namatanai found
# isangel found
# burnie found
# dunedin found
# beloha found
# machilipatnam found
# City not found. Skipping...
# yarada found
# arauca found
# farah found
# antofagasta found
# lasa found
# aitape found
# rio gallegos found
# baran found
# City not found. Skipping...
# martapura found
# camacha found
# benguela found
# chacaltianguis found
# wilmington found
# City not found. Skipping...
# pyapon found
# sibut found
# smoky lake found
# touros found
# miyako found
# trinidad found
# chipinge found
# coquimbo found
# pangoa found
# kourou found
# hovd found
# upata found
# leh found
# City not found. Skipping...
# brunico found
# sabha found
# key west found
# dores do indaia found
# ciudad bolivar found
# sacramento found
# kanniyakumari found
# angoche found
# port-gentil found
# City not found. Skipping...
# behbahan found
# mareeba found
# ondjiva found
# tual found
# khorixas found
# tilichiki found
# gao found
# tautira found
# zaysan found
# inhambane found
# kalmunai found
# mancora found
# barinas found
# opuwo found
# ust-uda found
# kalinovskaya found
# nizwa found
# trincomalee found
# City not found. Skipping...
# minab found
# shar found
# chapleau found
# City not found. Skipping...
# saint-pierre found
# sao jose da coroa grande found
# cabras found
# palmer found
# vanderhoof found
# coahuayana found
# houma found
# pechenga found
# City not found. Skipping...
# hervey bay found
# saint-georges found
# yeroham found
# teya found
# saint-augustin found
# zyryanka found
# ust-maya found
# atambua found
# zorritos found
# luderitz found
# lagoa found
# port-cartier found
# rosarito found
# City not found. Skipping...
# dauphin found
# dryden found
# pitimbu found
# City not found. Skipping...
# waddan found
# emerald found
# honiara found
# evensk found
# rocha found
# ashdod found
# City not found. Skipping...
# bandarbeyla found
# auki found
# City not found. Skipping...
# jumla found
# concepcion del oro found
# yerbogachen found
# ketchikan found
# usinsk found
# taoudenni found
# City not found. Skipping...
# City not found. Skipping...
# scarborough found
# along found
# ahipara found
# springfield found
# talisay found
# beipiao found
# brae found
# katobu found
# City not found. Skipping...
# City not found. Skipping...
# hukuntsi found
# korla found
# grand gaube found
# City not found. Skipping...
# okha found
# pokaran found
# manta found
# payo found
# backo gradiste found
# zharkovskiy found
# challapata found
# orsk found
# oranjestad found
# calatayud found
# la sarre found
# tazmalt found
# ayaviri found
# banepa found
# katangli found
# aklavik found
# kampene found
# muzhi found
# novikovo found
# belgrade found
# huarmey found
# City not found. Skipping...
# shkotovo found
# alekseyevskaya found
# sao sebastiao found
# linxia found
# yerofey pavlovich found
# makungu found
# miracatu found
# goderich found
# japura found
# City not found. Skipping...
# lata found
# banikoara found
# aanekoski found
# taltal found
# seimeni found
# santiago de cao found
# heishan found
# flagstaff found
# grand bank found
# pauini found
# general cepeda found
# el alto found
# bud found
# City not found. Skipping...
# awbari found
# shestakovo found
# ambon found
# manati found
# mehamn found
# berlevag found
# abu zabad found
# goascoran found
# werda found
# drumheller found
# saravena found
# boca do acre found
# vicuna found
# moranbah found
# bad waldsee found
# loandjili found
# ambilobe found
# dese found
# praia da vitoria found
# coihaique found
# vestmannaeyjar found
# otane found
# tulun found
# port augusta found
# bilma found
# tongchuan found
# khuzhir found
# iwanai found
# cabo san lucas found
# onalaska found
# sibolga found
# delta del tigre found
# havelock found
# smirnykh found
# gold coast found
# boa vista found
# quattro castella found
# port blair found
# adre found
# ajdabiya found
# darovskoy found
# stornoway found
# turayf found
# ananas found
# deshnok found
# kamina found
# san buenaventura found
# City not found. Skipping...
# khuzdar found
# letnyaya stavka found
# mandalgovi found
# marly found
# lovozero found
# marsa matruh found
# ndjole found
# sarakhs found
# derzhavinsk found
# roura found
# saint pete beach found
# zhangjiakou found
# hami found
# puerto colombia found
# lakatoro found
# san isidro found
# poya found
# City not found. Skipping...
# thornhill found
# kerema found
# santa maria found
# alexandria found
# yenagoa found
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 680

# %%
# Add the data to a new DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#                          City      Lat       Lng  Max Temp  Humidity  \
# 0                     Rikitea -23.1203 -134.9692     74.46        83
# 1                     Barentu  15.1139   37.5928     76.53        45
# 2                Saint George  37.1041 -113.5841     59.63        43
# 3                       Vardo  70.3705   31.1107     35.24        57
# 4  General Jose Eduvigis Diaz -27.1667  -58.4167     73.44        59
# 5               Srednekolymsk  67.4500  153.6833      1.72        92
# 6                     Hualmay -11.0964  -77.6139     63.25        83
# 7                    Qaqortoq  60.7167  -46.0333     36.10        60
# 8                  Butaritari   3.0707  172.7902     82.72        73
# 9                       Sitka  57.0531 -135.3300     49.89        57
#
#    Cloudiness  Wind Speed Weather Description
# 0         100       12.82       moderate rain
# 1          97        7.05     overcast clouds
# 2           1        1.99           clear sky
# 3         100       23.40     overcast clouds
# 4           0        7.20           clear sky
# 5          33        3.11    scattered clouds
# 6         100        9.55     overcast clouds
# 7          88        6.13     overcast clouds
# 8          15       10.29          few clouds
# 9          90        9.22          light rain

# %%
# Export the DataFrame as a CSV file, and save it as WeatherPy_Database.csv in the Weather_Database folder.
output_data_file = "Weather_Database/WeatherPy_Database.csv"
city_data_df.to_csv(output_data_file, index_label="City_ID")
